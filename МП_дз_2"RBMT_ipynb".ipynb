# %% [markdown]
# <a href="https://colab.research.google.com/github/jularch/compling/blob/main/%D0%9C%D0%9F_%D0%B4%D0%B7_2%22RBMT_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Машинный перевод. Домашнее задание

# %% [markdown]
# + Какую языковую пару обрабатывает ваша система?
#
#  ***Моя система будет обрабатывать французско-английскую языковую пару***
# + Какие виды анализа и предварительной обработки данных вы применяете?
#  ***Парсинг, аннотация и разметка.***
#
# + Какие языковые правила вам нужно описать?
#  ***Трансформацию синтаксиса и лексики. Помимо этого нужно будет описать структуру предложений каждого языка.***
#
# + Как ваша система будет генерировать результат, т.е. перевод?
#  ***Будет преобразовывать структуры к виду текста.***
#
# Дополнительно попробуйте ответить на вопрос:
#
# + Какие библиотеки NLP вы будете использовать?
#  ***Pattern, Polyglot, Gensim/SpaCy. Хотелось бы сравнить точность частеречных разметок данных библиотек.***

# %% [markdown]
# 1. принимаем на вход текст пользователя
# 2. обработка
#
#   2.1. приведение к общему регистру, удаление пунктуации, чисел.
#
#   2.2. токенизация
#
#   2.3. удаление стоп-слов
#
#   2.4. стемминг
#
#   2.5. лемматизация
#
#   3. парсинг
#
#   3.1. аннотация текста
#
#   3.2. разметка
# 4. перенос структуры
#
#   4.1. трансформация синтаксиса
#
#   4.2. трансформация лексики
#
#   4.3. описание структуры языка
# 5. сегментация текста
# 6. лексический трансфер
# 8. генерация слов
# 9. вывод на экран перевода текста
# ```
